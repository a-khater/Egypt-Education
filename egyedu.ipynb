# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Open file and specify Egypt

# %%
df = pd.read_excel("D:\datasets\Education-Egypt-Data Set.xls" , header=1 , index_cols=False ,sheet_name='Egypt Data' )

# %%
xl = df.loc[df['Country Code'] =='EGY']

# %%
x = ["Country Name" , "Country Code" , "Indicator Code"]

# %%
xn = xl.drop(x , axis=1)

# %%
xn.index = range(len(xn))

# %% [markdown]
# Plots

# %%
for x in range(len(xn)) :
    l=xn.iloc[x:x+1,:]
    o = l[['Indicator Name']]
    w = str(o)
    z=l.melt()
    z=z.iloc[1:]
    z.index = z['variable']
    z['value'].plot()
    plt.title(w)

    plt.show()

# %%
w
# Out:
# '                         Indicator Name\n108  Population ages 15-64 (% of total)'

# %%
z.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34 entries, 1980 to 2013
# Data columns (total 2 columns):
# variable    34 non-null object
# value       34 non-null object
# dtypes: object(2)
# memory usage: 816.0+ bytes

# %%
xtx=range(1980,2013)
